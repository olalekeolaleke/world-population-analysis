# %% [markdown]
# # Population Data Visualization
# ### pandas dataframe of median_age, age_structure

# %%
median_age = pd.read_csv("median_age.csv") 
print("________median_age by country_________")
median_age
# Out:
# ________median_age by country_________
#       country name  total  male  female
# 0            japan   47.3  46.0    48.7
# 1            india   27.9  27.2    28.6
# 2            china   37.4  36.5    38.4
# 3         thailand   37.7  36.6    38.7
# 4          vietnam   30.5  29.4    31.7
# 5         cambodia   25.3  24.6    26.0
# 6        singapore   34.6  34.5    34.7
# 7        indonesia   30.2  29.6    30.8
# 8           canada   42.2  40.9    43.5
# 9    united_states   38.1  36.8    39.4
# 10  united_kingdom   40.5  39.3    41.7
# 11         germany   47.1  46.0    48.2
# 12          france   41.4  39.6    43.1
# 13           italy   45.5  44.4    46.5
# 14           spain   42.7  41.5    43.9
# 15     philippines   23.5  23.1    24.0
# 16     south_korea   41.8  40.2    43.4
# 17          mexico   28.3  27.2    29.4
# 18         austria   44.0  42.8    45.1
# 19          poland   40.7  39.0    42.4
# 20        portugal   42.2  40.2    44.4
# ...

# %%
import pandas as pd
print("________age_structure by country_________")
age_structure = pd.read_csv("age_structure.csv") 
age_structure
# Out:
# ________age_structure by country_________
#       country name   0-14  15-24  25-54  54-64    65+
# 0            japan  12.84   9.64  37.50  12.15  27.87
# 1            india  27.34  17.90  41.08   7.45   6.24
# 2            china  17.15  12.78  48.51  10.75  10.81
# 3         thailand  16.93  14.17  46.32  12.00  10.58
# 4          vietnam  23.55  16.23  45.56   8.55   6.12
# 5         cambodia  31.01  18.36  40.68   5.69   4.25
# 6        singapore  12.82  16.56  50.53  10.46   9.63
# 7        indonesia  25.02  16.99  42.40   8.58   7.01
# 8           canada  15.44  11.85  39.99  14.10  18.63
# 9    united_states  18.73  13.27  39.45  12.91  15.63
# 10  united_kingdom  17.53  11.90  40.55  11.98  18.04
# 11         germany  12.82  10.09  40.45  14.58  22.06
# 12          france  18.53  11.79  37.78  12.42  19.48
# 13           italy  13.65   9.66  42.16  12.99  21.53
# 14           spain  15.38   9.58  44.91  12.14  17.98
# 15     philippines  33.39  19.16  36.99   5.97   4.49
# ...

# %% [markdown]
# ### Visualization of Crawled Data_Age Structure of 30 Countries

# %%
import matplotlib.pyplot as plt
# 주피터에 포함시키기 
# %matplotlib inline
import seaborn as sns

# %%
#set palette color of each country 
pkmn_type_colors = ['#78C850',  # japan
                    '#F08030',  # india
                    '#6890F0',  # china
                    '#A8B820',  # thailand
                    '#A8A878',  # vietnam
                    '#A040A0',  # cambodia
                    '#F8D030',  # singapore
                    '#E0C068',  # indonesia
                    '#EE99AC',  # canada
                    '#C03028',  # united_states
                    '#F85888',  # united_kingdom
                    '#B8A038',  # germany
                    '#705898',  # france
                    '#98D8D8',  # spain
                    '#7038F8',  # philippines
                    '#5BC7E5',  # south_korea
                    '#1c9ca5',  # mexico
                    '#6840A0',  # poland
                    '#52206a',  # portugal
                    '#6A1748',  # egypt
                    '#5BC7E5',  # denmark
                    '#09CAFF',  # australia
                    '#5BC7E5',  # cambodia
                    '#e2ceae',  # belgium
                    '#5BC7E5',  # sudan
                    '#E55BAD',  # russia
                    '#dc0e88',  # norway
                    '#E5D05B',  # saudi_arabia
                    
            
                    
                   ]

# %% [markdown]
# ## sorted bar graph (age proportion 65+)

# %%
sns.set(style="ticks")
plt.xticks(rotation=-40)  #x tick label rotation 
age_structure1= age_structure.sort_values(by='65+', ascending = False)  #sort values 
age_graph1= sns.barplot(x='country name',y='65+', data=age_structure1, palette=pkmn_type_colors) #draw bar plot 
age_graph1.figure.set_size_inches(20,9) #figure size 
age_graph1.axes.set_title('Aged Population by Country', fontsize=34,color="b",alpha=0.5)  #title
age_graph1.set_xlabel("Country Name",size = 20,color="r",alpha=0.5) #x_label setting
age_graph1.set_ylabel("Population % over 65",size = 20,color="g",alpha=0.5) #y_label setting
age_graph1.tick_params(labelsize=14,labelcolor="black")

# %% [markdown]
# ## sorted bar graph 4subplots (each age proportion )

# %%
import seaborn as sns
from matplotlib.gridspec import GridSpec

sns.set(style="whitegrid")
#sns.set_color_codes("Spectral")

plt.figure(2, figsize=(33,24)) #figure size
the_grid = GridSpec(2, 2)  #subplots  

plt.subplot(the_grid[0, 1],  title='Population % over 65+')
sns.barplot(x='country name',y='65+', data=age_structure1, palette=pkmn_type_colors) #bar plot setting  
plt.xticks(rotation=-50) # x label tick rotation 
plt.subplot(the_grid[0, 0], title='%Age 25-54')
sns.barplot(x='country name',y='25-54', data=age_structure1, palette=pkmn_type_colors)
plt.xticks(rotation=-50)
plt.subplot(the_grid[1, 1],  title='%Age 15-24')
sns.barplot(x='country name',y='15-24', data=age_structure1, palette=pkmn_type_colors)
plt.xticks(rotation=-50)
plt.subplot(the_grid[1, 0], title='%Age 54-64')
sns.barplot(x='country name',y='54-64', data=age_structure1, palette=pkmn_type_colors)
plt.xticks(rotation=-50)

plt.suptitle('Age Structure', fontsize=30,color="b",alpha=0.5)  #title setting 
age_graph1.tick_params(labelsize=9,labelcolor="blue")

# %% [markdown]
# ### Visualization of Crawled Data_Median Age of 17 Countries

# %%
import seaborn as sns
from matplotlib.gridspec import GridSpec

sns.set(style="whitegrid")
#sns.set_color_codes("Spectral")

plt.figure(3, figsize=(20,15))
the_grid = GridSpec(3, 3)  #subplots setting 

plt.subplot(the_grid[0, 1],  title='Total Median Age')
sns.barplot(x='country name',y='total', data=median_age, palette=pkmn_type_colors) #seaborn barplot setting 
plt.xticks(rotation=-40)
plt.subplot(the_grid[0, 0], title='Femal Median Age')
sns.barplot(x='country name',y='female', data=median_age, palette=pkmn_type_colors)
plt.xticks(rotation=-40)
plt.subplot(the_grid[0, 2],  title='Male Median Age')
sns.barplot(x='country name',y='male', data=median_age, palette=pkmn_type_colors)
plt.xticks(rotation=-40)


plt.suptitle('Median Age', fontsize=30,color="b",alpha=0.5)
# Out:
# Text(0.5,0.98,'Median Age')

# %%
import seaborn as sns
from matplotlib.gridspec import GridSpec


# sorted values 

sns.set(style="whitegrid")
#sns.set_color_codes("Spectral")

plt.figure(3, figsize=(20,15))
the_grid = GridSpec(3, 3)
median_age1= median_age.sort_values(by='total', ascending = False)  #sort values 

plt.subplot(the_grid[0, 1],  title='Total Median Age')
sns.barplot(x='country name',y='total', data=median_age1, palette=pkmn_type_colors)
plt.xticks(rotation=-40)
plt.subplot(the_grid[0, 0], title='Femal Median Age')
sns.barplot(x='country name',y='female', data=median_age1, palette=pkmn_type_colors)
plt.xticks(rotation=-40)
plt.subplot(the_grid[0, 2],  title='Male Median Age')
sns.barplot(x='country name',y='male', data=median_age1, palette=pkmn_type_colors)
plt.xticks(rotation=-40)


plt.suptitle('Median Age', fontsize=30,color="b",alpha=0.5)
# Out:
# Text(0.5,0.98,'Median Age')

# %%
unemployment = pd.read_csv("Unemployment.csv") 
                         
unemployment
print(unemployment)
# Out:
#   country name  2006  2007  2008  2009  2010  2011  2012 2013  2014
# 0        spain   8.4   8.2  11.0  17.0  19.0  21.0  24.0  26.  24.0
# 1  philippines   7.9   7.3   7.4   7.4   7.3   7.0   6.9  7.0   6.8
# 2  south_korea   3.4   3.2   3.1   3.6   3.7   3.4   3.2  3.1   3.5
# 3       mexico   3.5   3.6   3.8   5.3   5.2   5.1   4.8  4.9   4.7
# 4      austria   4.7   4.4   3.8   4.7   4.4   4.1   4.3  4.9   5.0
# 5       poland  13.0   9.6   7.1   8.1   9.6   9.6  10.0  10.   8.9
# 6     portugal   7.6   7.9   7.5   9.4  10.0  12.0  15.0  16.  13.0
# 7        egypt  10.0   9.2   8.6   9.3   9.2  10.0  12.0  13<  13.0
# 8      denmark   3.9   3.7   3.4   5.9   7.4   7.5   7.5  7.0   6.5
# 9    australia   4.7   4.3   4.2   5.5   5.2   5.0   5.2  5.6   6.0

# %%
unemp_melted = pd.melt(unemployment, id_vars = ['country name'],
                      value_vars = ['2006','2007','2008','2009','2010','2011','2012','2013','2014'],
                      value_name = 'unemployment',
                      var_name = 'country')
unemp_melted
# Out:
#    country name country unemployment
# 0         spain    2006          8.4
# 1   philippines    2006          7.9
# 2   south_korea    2006          3.4
# 3        mexico    2006          3.5
# 4       austria    2006          4.7
# 5        poland    2006           13
# 6      portugal    2006          7.6
# 7         egypt    2006           10
# 8       denmark    2006          3.9
# 9     australia    2006          4.7
# 10        spain    2007          8.2
# 11  philippines    2007          7.3
# 12  south_korea    2007          3.2
# 13       mexico    2007          3.6
# 14      austria    2007          4.4
# 15       poland    2007          9.6
# 16     portugal    2007          7.9
# 17        egypt    2007          9.2
# 18      denmark    2007          3.7
# 19    australia    2007          4.3
# 20        spain    2008           11
# 21  philippines    2008          7.4
# 22  south_korea    2008          3.1
# 23       mexico    2008          3.8
# ...

# %% [markdown]
# ### unemployment data line plot practice

# %%
import plotly 
plotly.tools.set_credentials_file(username='BOSUNG', api_key='pdpcFjaV9BMmS3s8Y5fz')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

title = 'Unemployment Rate Change'  #set title 

labels = ['spain','philliphines','south korea', 'mexico']

colors = ['rgb(67,67,67)', 'rgb(115,115,115)', 'rgb(49,130,189)', 'rgb(189,189,189)']  #set color of each line 

mode_size = [8, 8, 12, 8]

line_size = [2, 2, 4, 2]

x_data = [
    [2006, 2007, 2008, 2009, 2010, 2011, 2013, 2014],
    [2006, 2007, 2008, 2009, 2010, 2011, 2013, 2014],
    [2006, 2007, 2008, 2009, 2010, 2011, 2013, 2014],
    [2006, 2007, 2008, 2009, 2010, 2011, 2013, 2014],
  
]

y_data = [
    [8.4 ,  8.2,  11.0,17.0,19.0,21.0,24.0,26.0,24.0],
    [7.9 ,  7.3  , 7.4 ,  7.4 ,  7.3 ,  7.0 ,  6.9,  7.0 ,  6.8],
    [3.4 ,  3.2 ,  3.1 ,  3.6  , 3.7  , 3.4 ,  3.2,  3.1  , 3.5],
    [3.5 ,  3.6 ,  3.8  , 5.3 ,  5.2 ,  5.1  , 4.8,  4.9 ,  4.7],
]


traces = []

for i in range(0, 4):
    traces.append(go.Scatter(
        x=x_data[i],
        y=y_data[i],
        mode='lines',
        line=dict(color=colors[i], width=line_size[i]),
        connectgaps=True,
    ))

    traces.append(go.Scatter(
        x=[x_data[i][0], x_data[i][7]],
        y=[y_data[i][0], y_data[i][7]],
        mode='markers',
        marker=dict(color=colors[i], size=mode_size[i])
    ))

layout = go.Layout(
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickcolor='rgb(204, 204, 204)',
        tickwidth=2,
        ticklen=5,
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
    ),
    autosize=False,
    margin=dict(
        autoexpand=False,
        l=100,
        r=20,
        t=110,
    ),
    showlegend=False
)

annotations = []

# Adding labels
for y_trace, label, color in zip(y_data, labels, colors):
    # labeling the left_side of the plot
    annotations.append(dict(xref='paper', x=0.05, y=y_trace[0],
                                  xanchor='right', yanchor='middle',
                                  text=label + ' {}%'.format(y_trace[0]),
                                  font=dict(family='Arial',
                                            size=16),
                                  showarrow=False))
    # labeling the right_side of the plot
    annotations.append(dict(xref='paper', x=0.95, y=y_trace[7],
                                  xanchor='left', yanchor='middle',
                                  text='{}'.format(y_trace[7]),
                                  font=dict(family='Arial',
                                            size=16),
                                  showarrow=False))
# Title
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Unemployment Rate Change',
                              font=dict(family='Arial',
                                        size=30,
                                        color='rgb(37,37,37)'),
                              showarrow=False))
# Source
annotations.append(dict(xref='paper', yref='paper', x=0.5, y=-0.1,
                              xanchor='center', yanchor='top',
                              text='Source: PewResearch Center & ' +
                                   'Storytelling with data',
                              font=dict(family='Arial',
                                        size=12,
                                        color='rgb(150,150,150)'),
                              showarrow=False))

layout['annotations'] = annotations

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='unemployment rate')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~BOSUNG/6.embed" height="525px" width="100%"></iframe>
