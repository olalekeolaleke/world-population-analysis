# %%
# Importing Dependencies
import pandas as pd
import os
from sqlalchemy import create_engine

# %% [markdown]
# # Extract - Storing CSV into DataFrame

# %%
# Creating csv path and loading first data in Pandas DataFrame
csv_path = ("demo/Resources/World-population-by-countries-dataset.csv")
wrld_pop_df = pd.read_csv(csv_path)
wrld_pop_df.head()
# Out:
#      Country Name Country Code        1960        1961        1962  \
# 0     Afghanistan          AFG   8996967.0   9169406.0   9351442.0
# 1         Albania          ALB   1608800.0   1659800.0   1711319.0
# 2         Algeria          DZA  11057864.0  11336336.0  11619828.0
# 3  American Samoa          ASM     20127.0     20605.0     21246.0
# 4         Andorra          AND     13410.0     14378.0     15379.0
#
#          1963        1964        1965        1966        1967  ...      2012  \
# 0   9543200.0   9744772.0   9956318.0  10174840.0  10399936.0  ...  31161378
# 1   1762621.0   1814135.0   1864791.0   1914573.0   1965598.0  ...   2900401
# 2  11912800.0  12221675.0  12550880.0  12902626.0  13275020.0  ...  37383899
# 3     22029.0     22850.0     23675.0     24473.0     25235.0  ...     55669
# 4     16407.0     17466.0     18542.0     19646.0     20760.0  ...     82427
#
#        2013      2014      2015      2016      2017      2018      2019  \
# ...

# %%
# Creating csv path and loading first data in Pandas DataFrame
csv_path = ("demo/Resources/unemployment-analysis.csv")
unemp_rate_df = pd.read_csv(csv_path)
unemp_rate_df.head()
# Out:
#            Country Name Country Code   1991   1992   1993   1994   1995  \
# 0           Afghanistan          AFG  10.65  10.82  10.72  10.73  11.18
# 1                Angola          AGO   4.21   4.21   4.23   4.16   4.11
# 2               Albania          ALB  10.31  30.01  25.26  20.84  14.61
# 3  United Arab Emirates          ARE   1.87   1.84   1.85   1.81   1.80
# 4             Argentina          ARG   5.44   6.36  10.10  11.76  18.80
#
#     1996   1997   1998  ...   2012   2013   2014   2015   2016   2017   2018  \
# 0  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18  11.15
# 1   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41   7.42
# 2  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62  12.30
# 3   1.90   1.98   2.14  ...   2.18   2.04   1.91   1.77   1.64   2.46   2.35
# 4  17.11  14.82  12.65  ...   7.22   7.10   7.27   7.52   8.11   8.35   9.22
#
#     2019   2020   2021
# 0  11.22  11.71  13.28
# ...

# %% [markdown]
# # Data Cleaning and Transformation

# %%
# Renaming Country Name column
mapping = {wrld_pop_df.columns[0]:'country_name'}
transformed_data = wrld_pop_df.rename(columns=mapping)
transformed_data.head()
# Out:
#      country_name Country Code        1960        1961        1962  \
# 0     Afghanistan          AFG   8996967.0   9169406.0   9351442.0
# 1         Albania          ALB   1608800.0   1659800.0   1711319.0
# 2         Algeria          DZA  11057864.0  11336336.0  11619828.0
# 3  American Samoa          ASM     20127.0     20605.0     21246.0
# 4         Andorra          AND     13410.0     14378.0     15379.0
#
#          1963        1964        1965        1966        1967  ...      2012  \
# 0   9543200.0   9744772.0   9956318.0  10174840.0  10399936.0  ...  31161378
# 1   1762621.0   1814135.0   1864791.0   1914573.0   1965598.0  ...   2900401
# 2  11912800.0  12221675.0  12550880.0  12902626.0  13275020.0  ...  37383899
# 3     22029.0     22850.0     23675.0     24473.0     25235.0  ...     55669
# 4     16407.0     17466.0     18542.0     19646.0     20760.0  ...     82427
#
#        2013      2014      2015      2016      2017      2018      2019  \
# ...

# %%
# Renaming Country Name column
mapping = {unemp_rate_df.columns[0]:'country_name'}
renamed_data = unemp_rate_df.rename(columns=mapping)
# renamed_data

# %%
# Creating a filtered dataframe from specific columns

transformed_data_cols = ['country_name', '2011', '2012', '2013', '2014', '2015', 
                 '2016', '2017', '2018', '2019', '2020', '2021']

world_pop_df = transformed_data[transformed_data_cols].copy()

# Clean the data by dropping duplicates and setting the index
world_pop_df.drop_duplicates()

# Setting the Country Name column as index
# world_pop_df.set_index("country_name", inplace=True)

world_pop_df.head()
# Out:
#      country_name      2011      2012      2013      2014      2015      2016  \
# 0     Afghanistan  30117411  31161378  32269592  33370804  34413603  35383028
# 1         Albania   2905195   2900401   2895092   2889104   2880703   2876101
# 2         Algeria  36661438  37383899  38140135  38923688  39728020  40551398
# 3  American Samoa     55755     55669     55717     55791     55806     55739
# 4         Andorra     83748     82427     80770     79213     77993     77295
#
#        2017      2018      2019      2020      2021
# 0  36296111  37171922  38041757  38928341  39835428
# 1   2873457   2866376   2854191   2837849   2811666
# 2  41389174  42228415  43053054  43851043  44616626
# 3     55617     55461     55312     55197     55103
# 4     76997     77008     77146     77265     77354

# %%
# Creating a filtered dataframe from specific columns

renamed_data_cols = ['country_name', '2011', '2012', '2013', '2014', '2015', 
                 '2016', '2017', '2018', '2019', '2020', '2021']

unemp_rates_df = renamed_data[renamed_data_cols].copy()


# Clean the data by dropping duplicates and setting the index
unemp_rates_df.drop_duplicates()

# Setting the Country Name column as index
#unemp_rate_transformed.set_index("Country Name", inplace=True)

unemp_rates_df.head()
# Out:
#            country_name   2011   2012   2013   2014   2015   2016   2017  \
# 0           Afghanistan  11.05  11.34  11.19  11.14  11.13  11.16  11.18
# 1                Angola   7.36   7.35   7.37   7.37   7.39   7.41   7.41
# 2               Albania  13.48  13.38  15.87  18.05  17.19  15.42  13.62
# 3  United Arab Emirates   2.30   2.18   2.04   1.91   1.77   1.64   2.46
# 4             Argentina   7.18   7.22   7.10   7.27   7.52   8.11   8.35
#
#     2018   2019   2020   2021
# 0  11.15  11.22  11.71  13.28
# 1   7.42   7.42   8.33   8.53
# 2  12.30  11.47  13.33  11.82
# 3   2.35   2.23   3.19   3.36
# 4   9.22   9.84  11.46  10.90

# %% [markdown]
# # Connecting to local database

# %%
# Connecting to local database

protocol = 'postgresql'
username = '<postgres>'
password = '<akinbola1984>'
host = 'localhost'
port = 5432
database_name = 'WorldUnemployment_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
#engine = create_engine(rds_connection_string)
engine = create_engine('postgresql+psycopg2://postgres:akinbola1984@localhost/WorldUnemployment_db')

# %%
# Checking for tables

engine.table_names()
# Out:
# /var/folders/dl/lvr3mtqx0vz098qh46s4bv080000gn/T/ipykernel_83374/2519277686.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['world_population', 'unemployment_rate']

# %% [markdown]
# # Use pandas to load the first csv converted DataFrame into database

# %%
# Loading the reported_cases csv dataframe into prosgresql table

world_pop_df.to_sql(name='world_population', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
# ...

# %% [markdown]
# # Use pandas to load the second csv converted DataFrame into database

# %%
# Loading the immunization coverage dataframe into the progresql dataframe 

unemp_rates_df.to_sql(name='unemployment_rate', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Confirming data has been added by querying the world population table

# %%
# Dispalying the reported_cases table from the prosgresql database

pd.read_sql_query('select * from world_population', con=engine).head()

# %% [markdown]
# # Confirming data has been added by querying the unemployment rate table

# %%
# displaying the immunization table from the progresql database

pd.read_sql_query('select * from unemployment_rate', con=engine).head()

# %% [markdown]
# # Exporting Pandas DataFrame into csv

# %%
# Exporting Pandas DataFrame into csv
os.makedirs('clean-data', exist_ok=True)  
world_pop_df.to_csv('clean-data/world_population.csv')
unemp_rates_df.to_csv('clean-data/unemployment_rate.csv')
